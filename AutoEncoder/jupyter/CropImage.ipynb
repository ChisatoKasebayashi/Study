# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
img = Image.open("test_image.png").convert('L')
#img.show()
print(img.size)
#arrayImg = np.array(img).astype(np.float32)/255.
# Out:
# (140, 56)

# %%
# crop 28x28 image
c_img = []
arrayImg = np.empty([1,784])
for a in range(2):
    for b in range(5):
        c_img = img.crop((b*28,a*28,(b+1)*28,(a+1)*28))
        c_img = np.array(c_img)
        val = np.asarray(c_img).astype(np.float32)/255.
# Out:
# [[1.19838200e-311 1.19838197e-311 0.00000000e+000 1.19832279e-311
#   4.94065646e-324 1.19832279e-311 4.94065646e-324 1.19832279e-311
#   1.19680563e-311 1.19839357e-311 1.19680563e-311 5.23081357e-143
#   1.48219694e-323 1.38338381e-322 1.19831748e-311 4.94065646e-324
#   1.19832279e-311 2.33419537e-313 3.80984980e+180 1.19832279e-311
#   1.19830980e-311 1.19680563e-311 2.33419537e-313 4.94065646e-324
#   1.19832279e-311 9.88131292e-324 1.19832279e-311 1.19832279e-311
#   1.19680563e-311 8.73730929e-315 3.98450637e+252 1.19839357e-311
#   4.45619116e-313 3.86068906e-086 1.19839333e-311 3.34686866e+284
#   1.19831748e-311 4.88059032e-313 1.75630996e-152 1.19832279e-311
#   3.03181366e+180 1.19832279e-311 4.24399158e-313 0.00000000e+000
#   0.00000000e+000 7.90505033e-323 1.19832279e-311 1.19832279e-311
#   1.19832279e-311 2.33419537e-313 1.19680563e-311 1.19832279e-311
#   1.19832279e-311 8.73730929e-315 6.64320079e+246 3.77075632e+233
# ...
